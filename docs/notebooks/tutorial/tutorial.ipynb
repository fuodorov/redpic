# %% [markdown]
# # Tutotial

# %%
import redpic as rp
import kenv as kv
import numpy as np
import holoviews as hv
hv.extension('matplotlib')

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
rp.__version__
# Out:
# '0.7.35'

# %%
kv.__version__
# Out:
# '0.3.0.3'

# %% [markdown]
# ## Some plotting options

# %%
# %output size=100 backend='matplotlib' fig='png' dpi=300
# %opts Curve Scatter [aspect=3 show_grid=True]
# %opts Curve (linewidth=1 alpha=0.7 color='blue')
# %opts Scatter (alpha=0.7 s=0.5)

# %% [markdown]
# ## Define accelerator beamline parameters

# %%
acc = rp.accelerator.Accelerator(0.7, 6.7, 0.01)

# %%
#              Unique name,  z-position [m],  Ez [MV/m],  Ez(z) profile
acc.add_accel('Acc. 1',      4.096,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 2',      5.944,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 3',      6.796,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 4',      8.644,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 5',      9.496,          -1.1,         'Ez.dat')

# %%
#                 Unique name,  z-position [m],  Bz [T],  Bz(z) profile
acc.add_solenoid('Sol. 1',      0.45,           -0.058,   'Bz.dat')
acc.add_solenoid('Sol. 2',      0.957,           0.039,   'Bz.dat')
acc.add_solenoid('Sol. 3',      2.107,           0.025,   'Bz.dat')
acc.add_solenoid('Sol. 4',      2.907,           0.044,   'Bz.dat')
acc.add_solenoid('Sol. 5',      3.670,           0.04,    'Bz.dat')
acc.add_solenoid('Sol. 6',      4.570,           0.0595,  'Bz.dat')
acc.add_solenoid('Sol. 7',      5.470,           0.059,   'Bz.dat')
acc.add_solenoid('Sol. 8',      6.370,           0.060,   'Bz.dat')
acc.add_solenoid('Sol. 9',      7.270,           0.065,   'Bz.dat')
acc.add_solenoid('Sol. 10',     8.170,           0.065,   'Bz.dat')
acc.add_solenoid('Sol. 11',     9.070,           0.0655,  'Bz.dat')
acc.add_solenoid('Sol. 12',     9.970,           0.075,   'Bz.dat')

# %%
acc.compile()

# %%
dim_z  = hv.Dimension('z',  unit='m')
dim_Ez = hv.Dimension('Ez', unit='MV/m', label='$E_z$')
dim_Bz = hv.Dimension('Bz', unit='Gs', label='$B_z$')

# %%
z  = acc.z
z_Ez = hv.Curve((z, acc.Ez(z)), kdims=dim_z, vdims=dim_Ez)
z_Bz = hv.Curve((z, acc.Bz(z)*1e4), kdims=dim_z, vdims=dim_Bz)

# %%
(z_Ez + z_Bz).cols(1)
# Out:
# :Layout
#    .Curve.I  :Curve   [z]   (Ez)
#    .Curve.II :Curve   [z]   (Bz)

# %%
print(acc)
# Out:
# Accelerator structure.
# 	Solenoids:
# 	[ 0.45 m, -0.058 T, Bz.dat, Sol. 1, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 0.957 m, 0.039 T, Bz.dat, Sol. 2, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 2.107 m, 0.025 T, Bz.dat, Sol. 3, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 2.907 m, 0.044 T, Bz.dat, Sol. 4, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 3.67 m, 0.04 T, Bz.dat, Sol. 5, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 4.57 m, 0.0595 T, Bz.dat, Sol. 6, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 5.47 m, 0.059 T, Bz.dat, Sol. 7, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 6.37 m, 0.06 T, Bz.dat, Sol. 8, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 7.27 m, 0.065 T, Bz.dat, Sol. 9, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 8.17 m, 0.065 T, Bz.dat, Sol. 10, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.07 m, 0.0655 T, Bz.dat, Sol. 11, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.97 m, 0.075 T, Bz.dat, Sol. 12, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	Accelerating modules:
# 	[ 4.096 m, -1.1 T, Ez.dat, Acc. 1, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 5.944 m, -1.1 T, Ez.dat, Acc. 2, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 6.796 m, -1.1 T, Ez.dat, Acc. 3, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 8.644 m, -1.1 T, Ez.dat, Acc. 4, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.496 m, -1.1 T, Ez.dat, Acc. 5, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	Quadrupoles:
# 	Correctors x:
# 	Correctors y:

# %% [markdown]
# ## Define beam parameters

# %%
beam = rp.beam.UniformBeam(
    type=rp.constants.electron, 
    energy = 1.32,          # MeV
    current = 0.5e3,  # A
    radius_x = 48e-3, # initial r (m)
    radius_y = 48e-3, # initial r (m)
    radius_z = 3.5,
    radius_xp = 2*35.0e-3,     # initial r' (rad)
    radius_yp = 2*35.0e-3,     # initial r' (rad)
    x  = 0.0e-3,   # horizontal centroid position (m)
    xp = 0.0e-3,     # horizontal centroid angle (rad)
    y = 0,          # vertical centroid position (m)
    normalized_emittance = 200e-6*np.pi*3.58) # m*rad

# %%
beam.generate(10_000)
# Out:
# 2023-08-28 17:02:48,866 - redpic.beam.uniform - INFO - Generate a beam with a given distribution

# %%
beam.df
# Out:
#              x         y         z        px        py        pz
# 0     0.032830 -0.012823  1.193306  0.088205 -0.035319  1.743930
# 1    -0.016311  0.030628  0.513051 -0.051462  0.082374  1.761631
# 2     0.014776 -0.014077 -2.030264  0.037823 -0.032047  1.748615
# 3     0.006694 -0.015569 -3.275028  0.017898 -0.056079  1.747942
# 4    -0.010861 -0.020636 -1.684271 -0.022673 -0.064726  1.759610
# ...        ...       ...       ...       ...       ...       ...
# 9995  0.007556 -0.002513  0.697777  0.010923 -0.004916  1.749785
# 9996 -0.026547 -0.009765  1.399852 -0.085932 -0.032294  1.742962
# 9997 -0.000861  0.019968 -3.243776 -0.011340  0.052578  1.747591
# 9998 -0.036544  0.001781 -1.221667 -0.103624 -0.001660  1.769558
# 9999  0.006275 -0.017999  2.028198  0.027918 -0.048067  1.745854
#
# [10000 rows x 6 columns]

# %%
dim_x = hv.Dimension('x', unit='m', range=(-0.1, 0.1))
dim_y = hv.Dimension('y', unit='m', range=(-0.1, 0.1))
dim_z = hv.Dimension('z', unit='m', range=(acc.z_start, acc.z_stop))
dim_px = hv.Dimension('px', unit='MeV/c', label='$p_x$')
dim_py = hv.Dimension('py', unit='MeV/c', label='$p_y$')

# %%
beam_x_y = hv.Scatter(beam.df, kdims=[dim_x, dim_y])
beam_z_x = hv.Scatter(beam.df, kdims=[dim_z, dim_x])
beam_x_px = hv.Scatter(beam.df, kdims=[dim_x, dim_px])
beam_y_py = hv.Scatter(beam.df, kdims=[dim_y, dim_py])
# Out:
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:02:48,988 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:02:49,008 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:02:49,018 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:02:49,021 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim

# %%
(beam_x_y + beam_z_x + beam_x_px + beam_y_py).cols(2)
# Out:
# :Layout
#    .Scatter.I   :Scatter   [x,y]   (z,px,py,pz)
#    .Scatter.II  :Scatter   [z,x]   (y,px,py,pz)
#    .Scatter.III :Scatter   [x,px]   (y,z,py,pz)
#    .Scatter.IV  :Scatter   [y,py]   (x,z,px,pz)

# %%
print(beam)
# Out:
# Beam parameters:
# 	Type	electron
# 	Distribution	uniform
# 	Particles	10000
# 	Current	500 A
# 	Energy	1.320 MeV
# 	Total momentum	1.758 MeV/c
# 	Rel. factor	3.583
# 	Radius x	48.0 mm
# 	Radius y	48.0 mm
# 	Radius z	3.5 m
# 	Radius x prime	70.0 mrad
# 	Radius y prime	70.0 mrad
# 	Horizontal centroid position	0.0 mm
# 	Vertical centroid position	0.0 mm
# 	Horizontal centroid angle	0.0 mrad
# 	Vertical centroid angle	0.0 mrad
# 	Normalized emittance x	2249.4 mm*mrad
# 	Normalized emittance y	2249.4 mm*mrad

# %% [markdown]
# ## Run simulation

# %%
kv_sim = kv.Simulation(beam, acc)
kv_sim.track()

# %%
rp_sim = rp.solver.Simulation(beam, acc)
rp_sim.track()
# Out:
# z = 6.68 m (99.7 %)

# %% [markdown]
# ## Plot the simulation results

# %%
def plot(i):
    df = rp_sim.result[i]
    kv_z_x = hv.Curve(((acc.z, kv_sim.envelope_x(acc.z))), kdims=[dim_z], vdims=[dim_x], label='kenv')*\
    hv.Curve(((acc.parameter,-kv_sim.envelope_x(acc.z))), kdims=[dim_z], vdims=[dim_x])
    rp_z_x = hv.Scatter(df, kdims=[dim_z, dim_x], label='redpic')
    return rp_z_x*kv_z_x

# %%
items = [(i, plot(i)) for i in list(rp_sim.result.keys())]

holomap = hv.HoloMap(items, kdims = ['z'])

hv.output(holomap, widget_location='bottom')
# Out:
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,530 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,539 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,548 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,558 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,567 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,577 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,587 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,594 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,607 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,615 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,625 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,633 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,640 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,649 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,658 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,666 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,675 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,753 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,765 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-28 17:04:03,779 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# :HoloMap   [z]
#    :Overlay
#       .Scatter.Redpic :Scatter   [z,x]   (y,px,py,pz,Bx,By,Bz,Ex,Ey,Ez)
#       .Curve.Kenv     :Curve   [z]   (x)
#       .Curve.I        :Curve   [z]   (x)
