# %% [markdown]
# # REDPIC
# ## Tutotial
# [V. Fedorov](mailto:fuodorov1998@gmail.com)

# %%
import redpic as rp
import kenv as kv
import numpy as np
import holoviews as hv
hv.extension('matplotlib')

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
rp.__version__
# Out:
# '0.7.29'

# %%
kv.__version__
# Out:
# '0.3.0.3'

# %% [markdown]
# ## Some plotting options:

# %%
# %output size=150 backend='matplotlib' fig='png' dpi=200
# %opts Curve Scatter [aspect=3 show_grid=True]
# %opts Curve (linewidth=1 alpha=0.7 color='blue')
# %opts Scatter (alpha=0.7 s=0.5)

# %% [markdown]
# ## Define accelerator beamline parameters:

# %%
acc = rp.Accelerator(0.7, 6.7, 0.01)

# %%
#              Unique name,  z-position [m],  Ez [MV/m],  Ez(z) profile
acc.add_accel('Acc. 1',      4.096,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 2',      5.944,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 3',      6.796,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 4',      8.644,          -1.1,         'Ez.dat')
acc.add_accel('Acc. 5',      9.496,          -1.1,         'Ez.dat')

# %%
#                 Unique name,  z-position [m],  Bz [T],  Bz(z) profile
acc.add_solenoid('Sol. 1',      0.45,           -0.058,   'Bz.dat')
acc.add_solenoid('Sol. 2',      0.957,           0.039,   'Bz.dat')
acc.add_solenoid('Sol. 3',      2.107,           0.025,   'Bz.dat')
acc.add_solenoid('Sol. 4',      2.907,           0.044,   'Bz.dat')
acc.add_solenoid('Sol. 5',      3.670,           0.04,    'Bz.dat')
acc.add_solenoid('Sol. 6',      4.570,           0.0595,  'Bz.dat')
acc.add_solenoid('Sol. 7',      5.470,           0.059,   'Bz.dat')
acc.add_solenoid('Sol. 8',      6.370,           0.060,   'Bz.dat')
acc.add_solenoid('Sol. 9',      7.270,           0.065,   'Bz.dat')
acc.add_solenoid('Sol. 10',     8.170,           0.065,   'Bz.dat')
acc.add_solenoid('Sol. 11',     9.070,           0.0655,  'Bz.dat')
acc.add_solenoid('Sol. 12',     9.970,           0.075,   'Bz.dat')

# %%
acc.compile()

# %%
dim_z  = hv.Dimension('z',  unit='m')
dim_Ez = hv.Dimension('Ez', unit='MV/m', label='$E_z$')
dim_Bz = hv.Dimension('Bz', unit='Gs', label='$B_z$')

# %%
z  = acc.z
z_Ez = hv.Curve((z, acc.Ez(z)), kdims=dim_z, vdims=dim_Ez)
z_Bz = hv.Curve((z, acc.Bz(z)*1e4), kdims=dim_z, vdims=dim_Bz)

# %%
(z_Ez + z_Bz).cols(1)
# Out:
# :Layout
#    .Curve.I  :Curve   [z]   (Ez)
#    .Curve.II :Curve   [z]   (Bz)

# %%
print(acc)
# Out:
# Accelerator structure.
# 	Solenoids:
# 	[ 0.45 m, -0.058 T, Bz.dat, Sol. 1, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 0.957 m, 0.039 T, Bz.dat, Sol. 2, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 2.107 m, 0.025 T, Bz.dat, Sol. 3, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 2.907 m, 0.044 T, Bz.dat, Sol. 4, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 3.67 m, 0.04 T, Bz.dat, Sol. 5, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 4.57 m, 0.0595 T, Bz.dat, Sol. 6, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 5.47 m, 0.059 T, Bz.dat, Sol. 7, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 6.37 m, 0.06 T, Bz.dat, Sol. 8, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 7.27 m, 0.065 T, Bz.dat, Sol. 9, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 8.17 m, 0.065 T, Bz.dat, Sol. 10, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.07 m, 0.0655 T, Bz.dat, Sol. 11, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.97 m, 0.075 T, Bz.dat, Sol. 12, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	Accelerating modules:
# 	[ 4.096 m, -1.1 T, Ez.dat, Acc. 1, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 5.944 m, -1.1 T, Ez.dat, Acc. 2, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 6.796 m, -1.1 T, Ez.dat, Acc. 3, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 8.644 m, -1.1 T, Ez.dat, Acc. 4, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	[ 9.496 m, -1.1 T, Ez.dat, Acc. 5, 0.0 m, 0.0 rad, 0.0 m, 0.0 rad]
# 	Quadrupoles:
# 	Correctors x:
# 	Correctors y:

# %% [markdown]
# ## Define beam parameters:

# %%
beam = rp.Beam(
    type=rp.electron, 
    energy = 1.32,          # MeV
    current = 0.5e3,  # A
    radius_x = 48e-3, # initial r (m)
    radius_y = 48e-3, # initial r (m)
    radius_z = 3.5,
    radius_xp = 2*35.0e-3,     # initial r' (rad)
    radius_yp = 2*35.0e-3,     # initial r' (rad)
    x  = 0.0e-3,   # horizontal centroid position (m)
    xp = 0.0e-3,     # horizontal centroid angle (rad)
    y = 0,          # vertical centroid position (m)
    normalized_emittance = 200e-6*np.pi*3.58) # m*rad

# %%
beam.generate('KV', 10_000)
# Out:
# 2023-08-27 21:02:45,644 - redpic.beam - INFO - Generate a beam with a given distribution

# %%
beam.df
# Out:
#              x         y         z        px        py        pz
# 0     0.023815 -0.039789  3.091897  0.067608 -0.113716  1.741325
# 1    -0.034258  0.013820 -0.236793 -0.092572  0.039777  1.770349
# 2    -0.002149 -0.010904 -1.812305  0.004790 -0.033709  1.750325
# 3     0.006403  0.032087 -1.948713  0.027095  0.092989  1.764434
# 4    -0.030671  0.001035 -3.322623 -0.097140  0.007450  1.756798
# ...        ...       ...       ...       ...       ...       ...
# 9995  0.001978  0.047193 -2.975880  0.007193  0.136169  1.745755
# 9996 -0.017157 -0.009546 -1.754351 -0.058082 -0.034635  1.750151
# 9997  0.022351 -0.022976  1.704694  0.057193 -0.063891  1.775628
# 9998 -0.018414  0.014258 -2.594633 -0.058598  0.032762  1.768296
# 9999 -0.011880 -0.010030  2.823863 -0.034976 -0.018347  1.771718
#
# [10000 rows x 6 columns]

# %%
dim_x = hv.Dimension('x', unit='m', range=(-0.1, 0.1))
dim_y = hv.Dimension('y', unit='m', range=(-0.1, 0.1))
dim_z = hv.Dimension('z', unit='m', range=(acc.z_start, acc.z_stop))
dim_px = hv.Dimension('px', unit='MeV/c', label='$p_x$')
dim_py = hv.Dimension('py', unit='MeV/c', label='$p_y$')

# %%
beam_x_y = hv.Scatter(beam.df, kdims=[dim_x, dim_y])
beam_z_x = hv.Scatter(beam.df, kdims=[dim_z, dim_x])
beam_x_px = hv.Scatter(beam.df, kdims=[dim_x, dim_px])
beam_y_py = hv.Scatter(beam.df, kdims=[dim_y, dim_py])
# Out:
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:02:45,696 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:02:45,702 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:02:45,706 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:02:45,713 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim

# %%
(beam_x_y + beam_z_x + beam_x_px + beam_y_py).cols(2)
# Out:
# :Layout
#    .Scatter.I   :Scatter   [x,y]   (z,px,py,pz)
#    .Scatter.II  :Scatter   [z,x]   (y,px,py,pz)
#    .Scatter.III :Scatter   [x,px]   (y,z,py,pz)
#    .Scatter.IV  :Scatter   [y,py]   (x,z,px,pz)

# %%
print(beam)
# Out:
# Beam parameters:
# 	Type	electron
# 	Distribution	KV
# 	Particles	10000
# 	Current	500 A
# 	Energy	1.320 MeV
# 	Total momentum	1.758 MeV/c
# 	Rel. factor	3.583
# 	Radius x	48.0 mm
# 	Radius y	48.0 mm
# 	Radius z	3.5 m
# 	Radius x prime	70.0 mrad
# 	Radius y prime	70.0 mrad
# 	Horizontal centroid position	0.0 mm
# 	Vertical centroid position	0.0 mm
# 	Horizontal centroid angle	0.0 mrad
# 	Vertical centroid angle	0.0 mrad
# 	Normalized emittance x	2249.4 mm*mrad
# 	Normalized emittance y	2249.4 mm*mrad

# %% [markdown]
# ## Run simulation!

# %%
kv_sim = kv.Simulation(beam, acc)
kv_sim.track()

# %%
rp_sim = rp.Simulation(beam, acc)
rp_sim.track()
# Out:
# z = 6.68 m (99.7 %)

# %% [markdown]
# ## Plot the simulation results:

# %%
def plot(i):
    df = rp_sim.result[i]
    kv_z_x = hv.Curve(((acc.z, kv_sim.envelope_x(acc.z))), kdims=[dim_z], vdims=[dim_x], label='kenv')*\
    hv.Curve(((acc.parameter,-kv_sim.envelope_x(acc.z))), kdims=[dim_z], vdims=[dim_x])
    rp_z_x = hv.Scatter(df, kdims=[dim_z, dim_x], label='redpic')
    return rp_z_x*kv_z_x

# %%
items = [(i, plot(i)) for i in list(rp_sim.result.keys())]

hv.HoloMap(items, kdims = ['z'])
# Out:
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:52,989 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,002 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,013 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,020 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,026 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,032 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,040 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,046 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,054 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,063 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,071 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,119 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,130 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,142 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,154 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,171 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,186 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,206 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,225 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# WARNING:param.Scatter: Chart elements should only be supplied a single kdim
# 2023-08-27 21:03:53,241 - param.Scatter - WARNING - Chart elements should only be supplied a single kdim
# :HoloMap   [z]
#    :Overlay
#       .Scatter.Redpic :Scatter   [z,x]   (y,px,py,pz,Bx,By,Bz,Ex,Ey,Ez)
#       .Curve.Kenv     :Curve   [z]   (x)
#       .Curve.I        :Curve   [z]   (x)
