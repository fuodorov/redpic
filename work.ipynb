# %% [markdown]
# # How to run a simulation?

# %% [markdown]
# [Vyacheslav Fedorov](http://fuodorov.github.io)

# %% [markdown]
# ## Introduction

# %%
from redpic import *
import holoviews as hv
import numpy as np 
import pandas as pd
import glob

hv.notebook_extension('matplotlib')

# %output size=150 backend='matplotlib' fig='png' dpi=100

# %opts Curve [show_grid=True aspect=5] (linewidth=2 alpha=0.7)
# %opts Scatter [show_grid=True aspect=5] (alpha=0.7 s=5.0)
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
#   margin-right: 0;
# }
#
# .holotext {
#   padding-left:  0.5em;
#   padding-right: 0;
#   width: 100%;
# }
#
# .holowidgets .ui-resizable-se {
#   visibility: hidden
# }
#
# .holoframe > .ui-resizable-se {
#   visibility: hidden
# }
#
# .holowidgets .ui-resizable-s {
#   visibility: hidden
# }
#
#
# /* CSS rules for noUISlider based slider used by JupyterLab extension  */
#
# .noUi-handle {
#   width: 20px !important;
#   height: 20px !important;
#   left: -5px !important;
#   top: -5px !important;
# }
#
# .noUi-handle:before, .noUi-handle:after {
#   visibility: hidden;
#   height: 0px;
# }
#
# .noUi-target {
#   margin-left: 0.5em;
#   margin-right: 0.5em;
# }
# </style>
#
#
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ## Beam

# %%
beam = Beam(electron)

# %%
kv = Distribution(name='KV', x=0.050, y=0.050, z=1.5, px=0.01, py=0.01, pz=1.0)

# %%
beam.generate(kv, n=1e4)

# %%
dim_x = hv.Dimension('x', unit='m')
dim_y = hv.Dimension('y', unit='m')
dim_z = hv.Dimension('z', unit='m')
dim_px = hv.Dimension('px', unit='MeV/c', label='$p_x$')
dim_py = hv.Dimension('py', unit='MeV/c', label='$p_y$')
dim_pz = hv.Dimension('pz', unit='MeV/c', label='$p_z$')

# %%
x_y = hv.Scatter(beam.df, kdims=[dim_x, dim_y])

# %%
x_y
# Out:
# :Scatter   [x,y]   (z,px,py,pz)

# %% [markdown]
# ## Accelereator

# %%
acc = Accelerator(0, 10, 0.01)

# %%
#              Unique name,  z-position [m],  Ez [MV/m],  Ez(z) profile
acc.add_accel('Acc. 1',      1.5,            -1,         'Ez.dat')
acc.add_accel('Acc. 2',      3.5,            -1,         'Ez.dat')

# %%
#                 Unique name,  z-position [m],  Bz [T],  Bz(z) profile
acc.add_solenoid('Sol. 1',      1.0,             0.07,   'Bz.dat')
acc.add_solenoid('Sol. 2',      2.0,             0.08,   'Bz.dat')
acc.add_solenoid('Sol. 3',      3.0,             0.09,   'Bz.dat')
acc.add_solenoid('Sol. 4',      4.0,             0.10,   'Bz.dat')

# %%
acc.compile()

# %%
z = acc.z
dim_z  = hv.Dimension('z',  unit='m')
dim_Ez = hv.Dimension('Ez', unit='MV/m', label='$E_z$')
dim_Bz = hv.Dimension('Bz', unit='Gs', label='$B_z$')

# %%
z_Ez = hv.Curve((z, acc.Ez(z)), kdims=dim_z, vdims=dim_Ez)
z_Bz = hv.Curve((z, acc.Bz(z)*1e4), kdims=dim_z, vdims=dim_Bz)

# %%
(z_Bz+z_Ez).cols(1)
# Out:
# :Layout
#    .Curve.I  :Curve   [z]   (Bz)
#    .Curve.II :Curve   [z]   (Ez)

# %% [markdown]
# ## Simulation

# %%
sim = Simulation(beam, acc)

# %%
sim.track()
# Out:
# z = 9.98 m (99.8 %)

# %% [markdown]
# ## Plot

# %%
track_files = np.sort(glob.glob('*.*[0-9].csv'))
cols = ['x', 'y', 'z', 'px', 'py', 'pz', 'Ex', 'Ey', 'Ez', 'Bx', 'By', 'Bz']
i_to_plot = np.arange(0, len(track_files), 1)

# %%
def read_track(fname):
    df = pd.read_csv(fname, dtype='float32')
    df['x'] = df['x']*1e3 # mm
    df['y'] = df['y']*1e3 # mm
    df['Bx'] = df['Bx']*1e4
    df['By'] = df['By']*1e4
    df['Bz'] = df['Bz']*1e4
    #df = df.sample(n=100000)  
    return df

# %%
dim_x = hv.Dimension('x', unit='m')
dim_y = hv.Dimension('y', unit='m')
dim_z = hv.Dimension('z', unit='m')
dim_px = hv.Dimension('px', unit='MeV/c')
dim_py = hv.Dimension('py', unit='MeV/c')
dim_pz = hv.Dimension('pz', unit='MeV/c')
dim_Ex = hv.Dimension('Ex', unit='MV/m')
dim_Ey = hv.Dimension('Ey', unit='MV/m')
dim_Ez = hv.Dimension('Ez', unit='MV/m')
dim_Bx = hv.Dimension('Bx', unit='Gs')
dim_By = hv.Dimension('By', unit='Gs')
dim_Bz = hv.Dimension('Bz', unit='Gs')

# %%
def plot(i):
    fname = track_files[i]
    df = read_track(fname)
    z_x   = hv.Scatter(df, kdims=[dim_z, dim_x])
    z_pz  = hv.Scatter(df, kdims=[dim_z, dim_pz])
    z_Ez  = hv.Scatter(df, kdims=[dim_z, dim_Ez])
    z_Bz = hv.Scatter(df, kdims=[dim_z, dim_Bz])
    return (z_x + z_Bz + z_Ez + z_pz).cols(1)

# %%
items = [(i, plot(i)) for i in i_to_plot]

hv.HoloMap(items, kdims = ['Track file index']).collate()
# Out:
# :Layout
#    .Scatter.I   :HoloMap   [Track file index]
#       :Scatter   [z,x]   (Unnamed: 0,y,px,py,pz,Bx,By,Bz,Ex,Ey,Ez)
#    .Scatter.II  :HoloMap   [Track file index]
#       :Scatter   [z,Bz]   (Unnamed: 0,x,y,px,py,pz,Bx,By,Ex,Ey,Ez)
#    .Scatter.III :HoloMap   [Track file index]
#       :Scatter   [z,Ez]   (Unnamed: 0,x,y,px,py,pz,Bx,By,Bz,Ex,Ey)
#    .Scatter.IV  :HoloMap   [Track file index]
#       :Scatter   [z,pz]   (Unnamed: 0,x,y,px,py,Bx,By,Bz,Ex,Ey,Ez)
